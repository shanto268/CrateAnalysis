# %%
from MuDataFrame import * 

file = "processed_data/run408"
mdfo = MuDataFrame(file)

# %%
mdfo

# %%
mdf = mdfo.events_df
mdf
# Out:
#         event_num                  event_time  deadtime  l1hit  l2hit  l3hit  \
# 0               0  2021-02-12 17:28:56.139954         0      1      1      1
# 1               1  2021-02-12 17:28:56.234091         0      1      1      1
# 2               2  2021-02-12 17:28:56.399921         0      1      1      1
# 3               3  2021-02-12 17:28:56.680022         0      1      1      1
# 4               4  2021-02-12 17:28:56.790031         0      1      1      1
# ...           ...                         ...       ...    ...    ...    ...
# 124995     124995  2021-02-13 04:24:28.034749         0      1      1      1
# 124996     124996  2021-02-13 04:24:28.336579         0      1      1      1
# 124997     124997  2021-02-13 04:24:28.464885         0      1      1      1
# 124998     124998  2021-02-13 04:24:28.764773         0      1      1      1
# 124999     124999  2021-02-13 04:24:29.654920         0      1      1      1
#
# ...

# %%
mdf.columns
# Out:
# Index(['event_num', 'event_time', 'deadtime', 'l1hit', 'l2hit', 'l3hit',
#        'l4hit', 'r1hit', 'r2hit', 'r3hit', 'r4hit', 'SCh0', 'SCh1', 'SCh2',
#        'SCh3', 'SCh4', 'SCh5', 'SCh6', 'SCh7', 'SCh8', 'SCh9', 'SCh10',
#        'SCh11', 'L1', 'R1', 'L2', 'R2', 'L3', 'R3', 'L4', 'R4', 'ADC0', 'ADC1',
#        'ADC2', 'ADC3', 'ADC4', 'ADC5', 'ADC6', 'ADC7', 'ADC8', 'ADC9', 'ADC10',
#        'ADC11', 'TopCounter', 'BottomCounter', 'sumL1', 'sumL2', 'sumL3',
#        'sumL4', 'diffL1', 'diffL2', 'diffL3', 'diffL4', 'asymL1', 'asymL2',
#        'asymL3', 'asymL4', 'numLHit', 'theta_x1', 'theta_y1', 'theta_x2',
#        'theta_y2', 'z_angle', 'SmallCounter', 'Run_Num'],
#       dtype='object')

# %%
mdfo.getHistogram("z_angle")
