# %%
from MuDataFrame import *

mdfo_calib = MuDataFrame("/Volumes/mac_extended/Research/MT/proto1b/data_sets/tutorial/run656.csv")

# %%
mdf_calib = mdfo_calib.events_df

# %%
mdfo_calib.keepEvents("numLHit",8,"==")

# %%
mdfo_calib.events_df
# Out:
#        event_num                  event_time  deadtime  l1hit  l2hit  l3hit  \
# 0              0  2021-05-20 02:40:11.980749         0      1      1      1
# 1              1  2021-05-20 02:40:12.670748         0      1      1      1
# 4              4  2021-05-20 02:40:13.840823         0      1      1      1
# 5              5  2021-05-20 02:40:13.990657         0      1      1      1
# 6              6  2021-05-20 02:40:14.410943         0      1      1      1
# ...          ...                         ...       ...    ...    ...    ...
# 99992      99992  2021-05-20 13:18:29.305435         0      1      1      1
# 99993      99993  2021-05-20 13:18:29.875548         0      1      1      1
# 99994      99994  2021-05-20 13:18:30.125522         0      1      1      1
# 99996      99996  2021-05-20 13:18:30.965416         0      1      1      1
# 99999      99999  2021-05-20 13:18:32.575704         0      1      1      1
#
# ...

# %%
mdf_calib.columns
# Out:
# Index(['event_num', 'event_time', 'deadtime', 'l1hit', 'l2hit', 'l3hit',
#        'l4hit', 'r1hit', 'r2hit', 'r3hit', 'r4hit', 'SCh0', 'SCh1', 'SCh2',
#        'SCh3', 'SCh4', 'SCh5', 'SCh6', 'SCh7', 'SCh8', 'SCh9', 'SCh10',
#        'SCh11', 'L1', 'R1', 'L2', 'R2', 'L3', 'R3', 'L4', 'R4', 'ADC0', 'ADC1',
#        'ADC2', 'ADC3', 'ADC4', 'ADC5', 'ADC6', 'ADC7', 'ADC8', 'ADC9', 'ADC10',
#        'ADC11', 'TopCounter', 'BottomCounter', 'sumL1', 'sumL2', 'sumL3',
#        'sumL4', 'diffL1', 'diffL2', 'diffL3', 'diffL4', 'asymL1', 'asymL2',
#        'asymL3', 'asymL4', 'numLHit', 'theta_x1', 'theta_y1', 'theta_x2',
#        'theta_y2', 'z_angle', 'SmallCounter', 'speed', 'Run_Num'],
#       dtype='object')

# %%
mdf_calib["megan"] = mdf_calib.numLHit.values

# %%
mdf_calib
# Out:
#        event_num                  event_time  deadtime  l1hit  l2hit  l3hit  \
# 0              0  2021-05-20 02:40:11.980749         0      1      1      1
# 1              1  2021-05-20 02:40:12.670748         0      1      1      1
# 2              2  2021-05-20 02:40:13.220807         0      1      1      1
# 3              3  2021-05-20 02:40:13.730848         0      0      1      1
# 4              4  2021-05-20 02:40:13.840823         0      1      1      1
# ...          ...                         ...       ...    ...    ...    ...
# 99995      99995  2021-05-20 13:18:30.375574         0      0      0      1
# 99996      99996  2021-05-20 13:18:30.965416         0      1      1      1
# 99997      99997  2021-05-20 13:18:31.405694         0      1      0      1
# 99998      99998  2021-05-20 13:18:31.725719         0      1      1      0
# 99999      99999  2021-05-20 13:18:32.575704         0      1      1      1
#
# ...
