# %% [markdown]
# # Depth Reconstruction

# %%
zstack_file = "image_matrics_lead_bricks_gaps.csv"

# %%
I_matrices = np.loadtxt(zstack_file)

# %%
len(I_matrices[0])
# Out:
# 441

# %%
def generateZStack(I_matrices, interp, returnObj=False):
    imObjs = []
    for i in I_matrices:
        i = i.reshape(21, 21)
        fig = plt.figure(frameon=False)
        ax = plt.Axes(fig, [0., 0., 1., 1.])
        ax.set_axis_off()
        fig.add_axes(ax)
        imshowobj = ax.imshow(np.flip(i), aspect='auto', interpolation=interp)
        imshowobj.set_clim(0.9, 1.2)
        if not returnObj:
            plt.show()
        else:
            imObjs.append(imshowobj)
    if returnObj:
        return imObjs
    
def getImageMatrices(I_matrices):
    im = []
    size = int(len(I_matrices[0])**0.5)
    for i in I_matrices:
        i = i.reshape(size, size)
        im.append(i)
    return im


def getRatioPlot3DforZStack(images):
    for image in images:
        xsize, ysize = image.shape
        x = np.arange(0, xsize, 1)
        y = np.arange(0, ysize, 1)

        xs, ys = np.meshgrid(x, y)
        # z = calculate_R(xs, ys)
        zs = np.array(image)

        fig = plt.figure()
        ax = Axes3D(fig)
        ax.plot_surface(xs, ys, zs, rstride=1, cstride=1, cmap='viridis')
        plt.show()

def getRatioPlot3D(images, index):
        xsize, ysize = images[index].shape
        x = np.arange(0, xsize, 1)
        y = np.arange(0, ysize, 1)

        xs, ys = np.meshgrid(x, y)
        # z = calculate_R(xs, ys)
        zs = np.array(images[index])

        fig = plt.figure()
        ax = Axes3D(fig)
        ax.plot_surface(xs, ys, zs, rstride=1, cstride=1, cmap='viridis',linewidth=0,antialiased=False)
        #ax.plot_wireframe(xs, ys, zs,  rstride=1, cstride=1, cmap='viridis')
        plt.show()

# %%
I_matrices
# Out:
# array([[0.75207143, 0.75502073, 0.99404224, ..., 1.20331429, 0.97859897,
#         1.50414286],
#        [0.98380415, 0.86488344, 0.93650188, ..., 1.02142663, 1.09008594,
#         1.03264785],
#        [1.00442765, 0.93531265, 0.98469795, ..., 1.03262515, 1.03563403,
#         1.03640687],
#        ...,
#        [1.12672153, 1.10685506, 1.14953517, ..., 1.09990946, 1.14967352,
#         1.15468816],
#        [1.11582261, 1.07164008, 1.07232801, ..., 1.06401122, 1.11756926,
#         1.14100297],
#        [1.10641391, 1.12379401, 1.13695985, ..., 1.11012305, 1.11154353,
#         1.13833104]])

# %%
imo = generateZStack(I_matrices, 'none', True)
# Out:
# <ipython-input-37-0b3042b6be39>:5: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   fig = plt.figure(frameon=False)

# %%
images = getImageMatrices(I_matrices)

# %%
getRatioPlot3D(images,5)
# Out:
# <img src="data:image/png;base64,..." width="639.999990463257">
