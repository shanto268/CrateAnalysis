# %% [markdown]
# Study of hits through Layer 3 Channel 1 and onto Layer 4
#
# Simple adjustments can be made for other channels
#
# Further study in Layer 3 Channel 6 with theta constrained

# %% [markdown]
# # Study of TDC for Application in $\mu$ Track Reconstruction

# %% [markdown]
# Import the `MuDataFrame` Objects. Using the lead brick with gap as the `mdfo_lead` object.

# %%
from MuDataFrame import *

mdfo_calib = MuDataFrame("/Users/sc/Projects/Summer2021/Muons/dataFiles/calibration_new_set_up.csv")

mdf_calib = mdfo_calib.events_df

mdfo_calib.og_df = mdf_calib.copy()
mdfo_calib.show()
# Out:
#          Unnamed: 0  index  event_num                  event_time  deadtime  \
# 0                 0      0          0  2021-05-03 12:40:15.812760         0
# 1                 1      1          1  2021-05-03 12:40:16.502963         0
# 2                 2      2          2  2021-05-03 12:40:16.672924         0
# 3                 3      3          3  2021-05-03 12:40:16.892987         0
# 4                 4      4          4  2021-05-03 12:40:17.563102         0
# ...             ...    ...        ...                         ...       ...
# 2999995     2999995  99995    2999995  2021-05-20 13:18:30.375574         0
# 2999996     2999996  99996    2999996  2021-05-20 13:18:30.965416         0
# 2999997     2999997  99997    2999997  2021-05-20 13:18:31.405694         0
# 2999998     2999998  99998    2999998  2021-05-20 13:18:31.725719         0
# 2999999     2999999  99999    2999999  2021-05-20 13:18:32.575704         0
#
# ...

# %% [markdown]
# For a fixed $x$ coordinate (Tray 1) in top layer, we make cuts on different $y$ coordinates (Tray 2) and look into the TDC distribution on the **left channel of Tray 1**.

# %%
mdfo_calib.reload()
mdfo_calib.getChannelDiffPlots()

# %%
mdfo_calib.getHistogram("L3",range=(0,200))

# %% [markdown]
# The coordinates on Tray 1 ($x$) and Tray 2 ($y$) are as follows:

# %%
mdfo_calib.getHistogram("diffL3",range=(-75,75),nbins=50)

# %%
mdfo_calib.getHistogram("diffL4",range=(-75,75),nbins=50)

# %% [markdown]
# Making the cut on x.

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("diffL3",-57,"<=")

# %%
mdfo_calib.getHistogram("diffL3",range=(-75,75),nbins=50)

# %%
mdfo_calib.getHistogram("diffL4",range=(-75,75),nbins=50)

# %% [markdown]
# Going from left to right on the y-coordinate system.

# %%
mdfo_calib.keepEvents("diffL4",57,">=")

# %%
x3_1 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %% [markdown]
# Doing similar analyses for the other $y$ coordinates.

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("diffL3",-57,"<=")
mdfo_calib.keepEvents("diffL4",43,">=")
mdfo_calib.keepEvents("diffL4",59,"<=")

# %%
x3_2 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("diffL3",-57,"<=")

mdfo_calib.keepEvents("diffL4",34,">=")
mdfo_calib.keepEvents("diffL4",42,"<=")
mdfo_calib.getHistogram("diffL4",range=(-75,75),nbins=50)

# %%
x3_3 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("diffL3",-57,"<=")
mdfo_calib.keepEvents("diffL4",21,">=")
mdfo_calib.keepEvents("diffL4",30,"<=")
mdfo_calib.getHistogram("diffL4",range=(-75,75),nbins=50)

# %%
x3_4 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("diffL3",-57,"<=")

mdfo_calib.keepEvents("diffL4",11,">=")
mdfo_calib.keepEvents("diffL4",19,"<=")

# %%
x3_5 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("diffL3",-57,"<=")

mdfo_calib.keepEvents("diffL4",-5,">=")
mdfo_calib.keepEvents("diffL4",5,"<=")

# %%
x3_6 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("diffL3",-57,"<=")

mdfo_calib.keepEvents("diffL4",-17,">=")
mdfo_calib.keepEvents("diffL4",-10,"<=")

# %%
x3_7 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("diffL3",-57,"<=")

mdfo_calib.keepEvents("diffL4",-30,">=")
mdfo_calib.keepEvents("diffL4",-20,"<=")

# %%
x3_8 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("diffL3",-57,"<=")

mdfo_calib.keepEvents("diffL4",-38,">=")
mdfo_calib.keepEvents("diffL4",-32,"<=")

# %%
x3_9 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("diffL3",-57,"<=")

mdfo_calib.keepEvents("diffL4",-51,">=")
mdfo_calib.keepEvents("diffL4",-45,"<=")

# %%
x3_10 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("diffL3",-57,"<=")

mdfo_calib.keepEvents("diffL4",-51,"<")

# %%
x3_11 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %% [markdown]
# Comparing all the distributions.

# %%
import seaborn as sns

sns.color_palette("Spectral")
bins = 50
range = (60,110)
xval = 1

plt.hist(x3_1,label="1",bins=bins,range=range,histtype="step",color="red")
plt.hist(x3_2,label="2",bins=bins,range=range,histtype="step",color="blue")
plt.hist(x3_3,label="3",bins=bins,range=range,histtype="step",color="green")
plt.hist(x3_4,label="4",bins=bins,range=range,histtype="step",color="lawngreen")
plt.hist(x3_5,label="5",bins=bins,range=range,histtype="step",color="sienna")
plt.hist(x3_6,label="6",bins=bins,range=range,histtype="step",color="gold")
plt.hist(x3_7,label="7",bins=bins,range=range,histtype="step",color="black")
plt.hist(x3_8,label="8",bins=bins,range=range,histtype="step",color="maroon")
plt.hist(x3_9,label="9",bins=bins,range=range,histtype="step",color="olive")
plt.hist(x3_10,label="10",bins=bins,range=range,histtype="step",color="cyan")
plt.hist(x3_11,label="11",bins=bins,range=range,histtype="step",color="fuchsia")
plt.legend()
plt.xlabel("TDC (Left Channel)")
plt.title("Tray 3 (x = {})".format(xval))
#plt.savefig("tdc_hist_1.pdf")
plt.show()

# %%
data_x = [x3_1,x3_2,x3_3,x3_4,x3_5,x3_6,x3_7,x3_8,x3_9,x3_10,x3_11]
data_x_means = [np.mean(i) for i in data_x]
data_x_stds = [np.std(i) for i in data_x]
yvals = np.linspace(1,11,11)

# %%
plt.errorbar(x=yvals, y=data_x_means, marker='x', yerr=data_x_stds,
             mec='red', ms=9, capsize=5) #solid_capstyle='projecting'
plt.xlabel("y coordinates")
plt.ylabel("Mean of TDC")
plt.title("Tray 3 (x = {})".format(1))
plt.savefig("tdc_dist_3_Mu.pdf")

# %% [markdown]
# # Accurate Peak Fitting Code

# %%
from MuDataFrame import *

mdfo_calib = MuDataFrame("/Users/sc/Projects/Summer2021/Muons/dataFiles/calibration_new_set_up.csv")

mdf_calib = mdfo_calib.events_df

mdfo_calib.og_df = mdf_calib.copy()
mdfo_calib.show()
# Out:
#          Unnamed: 0  index  event_num                  event_time  deadtime  \
# 0                 0      0          0  2021-05-03 12:40:15.812760         0
# 1                 1      1          1  2021-05-03 12:40:16.502963         0
# 2                 2      2          2  2021-05-03 12:40:16.672924         0
# 3                 3      3          3  2021-05-03 12:40:16.892987         0
# 4                 4      4          4  2021-05-03 12:40:17.563102         0
# ...             ...    ...        ...                         ...       ...
# 2999995     2999995  99995    2999995  2021-05-20 13:18:30.375574         0
# 2999996     2999996  99996    2999996  2021-05-20 13:18:30.965416         0
# 2999997     2999997  99997    2999997  2021-05-20 13:18:31.405694         0
# 2999998     2999998  99998    2999998  2021-05-20 13:18:31.725719         0
# 2999999     2999999  99999    2999999  2021-05-20 13:18:32.575704         0
#
# ...

# %%
from scipy.stats import gaussian_kde

def getIntersections(t, curve1, curve2, doPlot=True):
    intersections = []
    xvals = []
    prev_dif = 0
    t0, prev_c1, prev_c2 = None, None, None
    for t1, c1, c2 in zip(t, curve1, curve2):
        new_dif = c2 - c1
        if np.abs(new_dif) < 1e-12:  # found an exact zero, this is very unprobable
            intersections.append((t1, c1))
        elif new_dif * prev_dif < 0:
            denom = prev_dif - new_dif
            xvals.append((-new_dif * t0 + prev_dif * t1) / denom)
            intersections.append(((-new_dif * t0 + prev_dif * t1) / denom,
                                  (c1 * prev_c2 - c2 * prev_c1) / denom))
        t0, prev_c1, prev_c2, prev_dif = t1, c1, c2, new_dif

    if doPlot:
        fig, ax = plt.subplots()
        ax.plot(t, curve1, 'b-')
        ax.plot(t, curve2, 'r-')
        ax.plot(*zip(*intersections), 'kx', ms=5)
        plt.show()
    
    diffs = np.diff(xvals)
    return xvals


def TDCHisto(i, j, tdc_hist, bins, range, colors):
    if i == 9:
        range = (120, 170)
    elif i >= 7:
        range = (120, 160)
    elif i >= 6:
        range = (100, 150)
    elif i >= 4:
        range = (90, 140)
    else:
        range = (70, 120)
    plt.hist(tdc_hist, label=str(j+1), bins=bins,
             range=range, histtype="step", color=colors[j])
    plt.legend()
    plt.xlabel("TDC (Left Channel)")
    plt.title("Tray 3 (x = {})".format(i+2))
    

def TDCMean_og(i, tdc_hist):
    data_x = tdc_hist
    data_x_means = [np.mean(i) for i in data_x]
    data_x_stds = [np.std(i) for i in data_x]
    yvals = np.linspace(1, 11, 11)
    plt.scatter(yvals, data_x_means)
    plt.xlabel("y coordinates")
    plt.ylabel("Mean of TDC")
    plt.title("Tray 3 (x = {})".format(i+2))
    plt.show()
    plt.scatter(yvals, data_x_stds)
    plt.xlabel("y coordinates")
    plt.ylabel("Std of TDC")
    plt.title("Tray 3 (x = {})".format(i+2))
    plt.show()


def TDCMean(i, tdc_hist,name=""):
    data_x = tdc_hist
    data_x_means = [np.mean(i) for i in data_x]
    data_x_stds = [np.std(i) for i in data_x]
    yvals = np.linspace(1, 11, 11)
    plt.errorbar(x=yvals, y=data_x_means, marker='x', yerr=data_x_stds, mec='red', ms=9, capsize=5)#solid_capstyle='projecting'
    plt.xlabel("y coordinates")
    plt.ylabel("Mean of TDC")
    plt.title("Tray 1 (x = {})".format(i+2))
    plt.savefig("tdc_dist_{}_{}.pdf".format(i+2,name))
    plt.clf()
  #  plt.show()

def getTDCInfo(i, tdc_hist):
    data_x = tdc_hist
    data_x_means = [np.mean(i) for i in data_x]
    data_x_stds = [np.std(i) for i in data_x]
    return data_x_means,data_x_stds

def getIndividualPeaks(mdfo,
                       coord,
                       thresh=0.002,
                       bw=0.009,
                       axes=[-75, 75],
                       N=150,
                       doPlot=True):
    data = mdfo.get(coord)

    density1 = gaussian_kde(data, bw_method=bw)
    xs = np.linspace(axes[0], axes[1], N)

    t = xs
    curve1 = density1(xs)
    curve2 = len(curve1) * [thresh]
    vals = getIntersections(t, curve1, curve2,doPlot=doPlot)
    vals = np.reshape(vals,[11,2])
    return vals

# %%
from scipy.stats import gaussian_kde

mdfo_calib.reload()
mdfo_calib.keep4by4Events()

data = mdfo_calib.get("diffL4")
#bandwidth = 0.9

density1 = gaussian_kde(data)
xs = np.linspace(-75,75,150)
plt.plot(xs,density1(xs))
plt.hist(data,density=True,alpha=0.3,range=(-75,75),bins=150)
plt.hlines(0.002,xs[0],xs[-1])
plt.show()

# %%
mdfo_calib.reload()
mdfo_calib.keep4by4Events()
data = mdfo_calib.get("diffL4")
bandwidth = 0.03
density1 = gaussian_kde(data, bw_method=bandwidth)
xs = np.linspace(-75,75,150)
t = xs
curve1 = density1(xs)
curve2 = len(curve1) * [0.002]
vals = getIntersections(t, curve1, curve2)

# %%
L3 = np.reshape(vals,[11,2])
L3
# Out:
# array([[-66.9281209 , -59.106999  ],
#        [-55.62471378, -45.28067916],
#        [-42.04504293, -34.130992  ],
#        [-30.68055058, -22.02097719],
#        [-19.97473986,  -8.65643129],
#        [ -4.44269661,   2.87750773],
#        [  5.99458646,  17.2573957 ],
#        [ 20.63497637,  28.55247938],
#        [ 32.1066836 ,  40.01127061],
#        [ 43.67528741,  53.66442648],
#        [ 57.08165979,  64.71006405]])

# %%
i = 1
TDCS_L3 = []

for peak in L3:
    if i != 1: #not using the first peak as analysis already done in Section 1
    # isolate the peaks
        mdfo_calib.reload()
        mdfo_calib.keep4by4Events()
        mdfo_calib.keepEvents("diffL3",peak[1],"<=")
        mdfo_calib.keepEvents("diffL3",peak[0],">=")
    # generate the L2 peaks
        L4 = getIndividualPeaks(mdfo_calib, "diffL4",thresh=0.002,bw=0.03,doPlot=False)
        for each_peak in L4:
            mdfo_calib.reload()
            mdfo_calib.keep4by4Events()
            mdfo_calib.keepEvents("diffL3",peak[1],"<=")
            mdfo_calib.keepEvents("diffL3",peak[0],">=")
            
            mdfo_calib.keepEvents("diffL4",each_peak[1],"<=")
            mdfo_calib.keepEvents("diffL4",each_peak[0],">=")
            # store the tdcs
            TDCS_L3.append(mdfo_calib.get("L3"))
            #mdfo_calib.getHistogram("L1",range=(0,200))            
            #mdfo_calib.getHistogram("diffL2",range=(-75,75),nbins=50)
    i+=1

# %%
len(TDCS_L3)

# %%
TDCS_L3 = np.reshape(TDCS_L3,[9,11])
TDCS_L3

# %%
import seaborn as sns

sns.color_palette("Spectral")
bins = 50

colors = ["red","blue","green","lawngreen","sienna","gold","black","maroon","olive","cyan","fuchsia"]

info_tdc = []

for i, tdc_hists in enumerate(TDCS_L3):
    TDCMean(i, tdc_hists)
    info_tdc.append(getTDCInfo(i, tdc_hists))

    
    for j,tdc_hist in enumerate(tdc_hists):
        TDCHisto(i,j,tdc_hist,bins,range,colors)
    plt.savefig("tdc_hist_{}.pdf".format(i+2))
    plt.clf()
    plt.show()

# %%
x3_y_l1 = (data_x_means, data_x_stds)

info_tdc.insert(0,x3_y_l1)

# %% [markdown]
# # 'Straight' Muon Study of L3 Ch6 - Theta constrained to $\mu$ (9.391)

# %%
from MuDataFrame import *

mdfo_calib = MuDataFrame("/Users/sc/Projects/Summer2021/Muons/dataFiles/calibration_new_set_up.csv")

mdf_calib = mdfo_calib.events_df

mdfo_calib.show()
# Out:
#          Unnamed: 0  index  event_num                  event_time  deadtime  \
# 0                 0      0          0  2021-05-03 12:40:15.812760         0
# 1                 1      1          1  2021-05-03 12:40:16.502963         0
# 2                 2      2          2  2021-05-03 12:40:16.672924         0
# 3                 3      3          3  2021-05-03 12:40:16.892987         0
# 4                 4      4          4  2021-05-03 12:40:17.563102         0
# ...             ...    ...        ...                         ...       ...
# 2999995     2999995  99995    2999995  2021-05-20 13:18:30.375574         0
# 2999996     2999996  99996    2999996  2021-05-20 13:18:30.965416         0
# 2999997     2999997  99997    2999997  2021-05-20 13:18:31.405694         0
# 2999998     2999998  99998    2999998  2021-05-20 13:18:31.725719         0
# 2999999     2999999  99999    2999999  2021-05-20 13:18:32.575704         0
#
# ...

# %%
mdfo_calib.reload()
mdfo_calib.getChannelDiffPlots()

# %%
mdfo_calib.getHistogram("diffL3",range=(-75,75),nbins=50)

# %%
mdfo_calib.getHistogram("diffL4",range=(-75,75),nbins=50)

# %%
mdfo_calib.getHistogram("z_angle")

# %% [markdown]
# Make cuts limiting angle to less than or equal to the mean theta

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",9.391,"<=")

# %%
mdfo_calib.getHistogram("z_angle")

# %% [markdown]
# Only look at events going through L3 Ch6 with theta less than or equal to 9.391

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",9.391,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

# %%
mdfo_calib.getHistogram("diffL3",range=(-75,75),nbins=50)

# %% [markdown]
# Exploring 'Straight' muon hits in L4 that passed through L3 Ch6

# %%
mdfo_calib.keepEvents("diffL4",57,">=")
x6_1 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",9.391,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",43,">=")
mdfo_calib.keepEvents("diffL4",59,"<=")
x6_2 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",9.391,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",34,">=")
mdfo_calib.keepEvents("diffL4",42,"<=")
x6_3 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",9.391,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",21,">=")
mdfo_calib.keepEvents("diffL4",30,"<=")
x6_4 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",9.391,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",11,">=")
mdfo_calib.keepEvents("diffL4",19,"<=")
x6_5 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",9.391,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",-5,">=")
mdfo_calib.keepEvents("diffL4",5,"<=")
x6_6 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",9.391,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",-17,">=")
mdfo_calib.keepEvents("diffL4",-10,"<=")
x6_7 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",9.391,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",-30,">=")
mdfo_calib.keepEvents("diffL4",-20,"<=")
x6_8 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",9.391,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",-38,">=")
mdfo_calib.keepEvents("diffL4",-32,"<=")
x6_9 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",9.391,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",-51,">=")
mdfo_calib.keepEvents("diffL4",-45,"<=")
x6_10 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",9.391,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",-51,"<")
x6_11 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
import seaborn as sns

sns.color_palette("Spectral")
bins = 50
range = (60,110)
xval = 6

plt.hist(x6_1,label="1",bins=bins,range=range,histtype="step",color="red")
plt.hist(x6_2,label="2",bins=bins,range=range,histtype="step",color="blue")
plt.hist(x6_3,label="3",bins=bins,range=range,histtype="step",color="green")
plt.hist(x6_4,label="4",bins=bins,range=range,histtype="step",color="lawngreen")
plt.hist(x6_5,label="5",bins=bins,range=range,histtype="step",color="sienna")
plt.hist(x6_6,label="6",bins=bins,range=range,histtype="step",color="gold")
plt.hist(x6_7,label="7",bins=bins,range=range,histtype="step",color="black")
plt.hist(x6_8,label="8",bins=bins,range=range,histtype="step",color="maroon")
plt.hist(x6_9,label="9",bins=bins,range=range,histtype="step",color="olive")
plt.hist(x6_10,label="10",bins=bins,range=range,histtype="step",color="cyan")
plt.hist(x6_11,label="11",bins=bins,range=range,histtype="step",color="fuchsia")
plt.legend()
plt.xlabel("TDC (Left Channel)")
plt.title("Tray 3 (x = {}) $\Theta < \mu$".format(xval))
#plt.savefig("tdc_hist_1.pdf")
plt.show()

# %%
data_x = [x6_1,x6_2,x6_3,x6_4,x6_5,x6_6,x6_7,x6_8,x6_9,x6_10,x6_11]
data_x_means = [np.mean(i) for i in data_x]
data_x_stds = [np.std(i) for i in data_x]
yvals = np.linspace(1,11,11)

plt.errorbar(x=yvals, y=data_x_means, marker='x', yerr=data_x_stds,
             mec='red', ms=9, capsize=5) #solid_capstyle='projecting'
plt.xlabel("y coordinates")
plt.ylabel("Mean of TDC")
plt.title("Tray 3 (x = {})".format(1))
plt.savefig("tdc_dist_L3Ch6.pdf")

# %% [markdown]
# # 'Straight' Muon Study of L3 Ch6 - Theta constrained to $\mu$/2 (4.6955)

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",4.6955,"<=")
mdfo_calib.getHistogram("z_angle")

# %% [markdown]
# Notice capital X here ( X6_# ) represents Layer 6 channels with theta limited to $\mu$/2

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",4.6955,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",57,">=")
X6_1 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",4.6955,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",43,">=")
mdfo_calib.keepEvents("diffL4",59,"<=")
X6_2 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",4.6955,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",34,">=")
mdfo_calib.keepEvents("diffL4",42,"<=")
X6_3 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",4.6955,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",21,">=")
mdfo_calib.keepEvents("diffL4",30,"<=")
X6_4 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",4.6955,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",11,">=")
mdfo_calib.keepEvents("diffL4",19,"<=")
X6_5 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",4.6955,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",-5,">=")
mdfo_calib.keepEvents("diffL4",5,"<=")
X6_6 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",4.6955,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",-17,">=")
mdfo_calib.keepEvents("diffL4",-10,"<=")
X6_7 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",4.6955,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",-30,">=")
mdfo_calib.keepEvents("diffL4",-20,"<=")
X6_8 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",4.6955,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",-38,">=")
mdfo_calib.keepEvents("diffL4",-32,"<=")
X6_9 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",4.6955,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",-51,">=")
mdfo_calib.keepEvents("diffL4",-45,"<=")
X6_10 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
mdfo_calib.reload()
mdfo_calib.keepEvents("z_angle",4.6955,"<=")
mdfo_calib.keepEvents("diffL3",-8,">=")
mdfo_calib.keepEvents("diffL3",8,"<=")

mdfo_calib.keepEvents("diffL4",-51,"<")
X6_11 = mdfo_calib.get("L3")
mdfo_calib.getHistogram("L3",range=(0,200))

# %%
import seaborn as sns

sns.color_palette("Spectral")
bins = 50
range = (60,110)
xval = 6

plt.hist(X6_1,label="1",bins=bins,range=range,histtype="step",color="red")
plt.hist(X6_2,label="2",bins=bins,range=range,histtype="step",color="blue")
plt.hist(X6_3,label="3",bins=bins,range=range,histtype="step",color="green")
plt.hist(X6_4,label="4",bins=bins,range=range,histtype="step",color="lawngreen")
plt.hist(X6_5,label="5",bins=bins,range=range,histtype="step",color="sienna")
plt.hist(X6_6,label="6",bins=bins,range=range,histtype="step",color="gold")
plt.hist(X6_7,label="7",bins=bins,range=range,histtype="step",color="black")
plt.hist(X6_8,label="8",bins=bins,range=range,histtype="step",color="maroon")
plt.hist(X6_9,label="9",bins=bins,range=range,histtype="step",color="olive")
plt.hist(X6_10,label="10",bins=bins,range=range,histtype="step",color="cyan")
plt.hist(X6_11,label="11",bins=bins,range=range,histtype="step",color="fuchsia")
plt.legend()
plt.xlabel("TDC (Left Channel)")
plt.title("Tray 3 (X = {}) $\Theta < \mu/2$".format(xval))
#plt.savefig("tdc_hist_1.pdf")
plt.show()

# %%
data_x = [X6_1,X6_2,X6_3,X6_4,X6_5,X6_6,X6_7,X6_8,X6_9,X6_10,X6_11]
data_x_means = [np.mean(i) for i in data_x]
data_x_stds = [np.std(i) for i in data_x]
yvals = np.linspace(1,11,11)

plt.errorbar(x=yvals, y=data_x_means, marker='x', yerr=data_x_stds,
             mec='red', ms=9, capsize=5) #solid_capstyle='projecting'
plt.xlabel("y coordinates")
plt.ylabel("Mean of TDC")
plt.title("Tray 3 (X = {})".format(1))
plt.savefig("tdc_dist_L3Ch6_Muover2.pdf")
